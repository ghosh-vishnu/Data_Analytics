# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tips=pd.read_csv(r"C:\Users\Vishnu\Downloads\tips.csv")

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# SCATTER PLOT

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.title("Total Bill Vs Tip")
plt.show()

# %%
# plt.scatter()
plt.scatter(df['total_bill'],df['tip'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='sex', y='size', data=df)
plt.title("Gender wise Total Partners")
plt.show()

# %%
sns.scatterplot(x='sex', y='day', data=df)
plt.title("Day Wise Gender Ratio")
plt.show()

# %%
df.value_counts(df['day'])
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# Line plot

# %%
sns.lineplot(x='size',y='tip',data=df)
plt.title("Partner Vs Tip")
plt.show()

# %%
sns.lineplot(x='sex',y='tip',data=df)
plt.title("Gender Wise Tip")
plt.show()

# %% [markdown]
# Barplot

# %%
sns.barplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.barplot(x='sex',y='total_bill',data=df)
plt.show()

# %%
sns.barplot(x='sex',y='tip',data=df)
plt.show()

# %%
sns.barplot(x='smoker',y='sex',data=df)
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=df)
plt.title("Avg Bill per day")
plt.show()

# %%
sns.countplot(x="sex",data=df)
plt.title("Total Male or Female")
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x='day',y='total_bill',data=df)
plt.title("Boxplot - Outliers Detection")
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=df)
plt.title("Distribution")
plt.show()

# %%
sns.violinplot(x='sex',y='total_bill',data=df)
plt.title("Distribution")
plt.show()

# %%
sns.violinplot(x='sex',y='tip',data=df)
plt.title("Distribution")
plt.show()

# %%
sns.violinplot(x='sex',y='smoker',data=df)
plt.title("Distribution")
plt.show()

# %%
sns.pairplot(df)

# %%
import seaborn as sns

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind="reg")

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind="kde")

# %%
plt.bar(df['day'],df['total_bill'],kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.bar(df['day'],df['total_bill'],kind='bar')
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# ...

# %%
plt.plot(x='total_bill',y='tip',kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plt.plot(x='total_bill',y='tip',kind='bar')
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...

# %%
plt.plot(df['total_bill'],df['tip'],kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 plt.plot(df['total_bill'],df['tip'],kind='bar')
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File c:\Users\Vishnu\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...

# %%
import scipy
df.groupby('day')['total_bill'].mean().plot(kind='kde',color='Red')
# Out:
# C:\Users\Vishnu\AppData\Local\Temp\ipykernel_19784\3616442189.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day')['total_bill'].mean().plot(kind='kde',color='Red')

# %%
pip install scipy
# Out:
# ...
#   Using cached scipy-1.16.3-cp314-cp314-win_amd64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.16.3-cp314-cp314-win_amd64.whl (39.4 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
corr=df.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 corr=df.corr()
#
# NameError: name 'df' is not defined
